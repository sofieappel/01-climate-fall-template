# %% [markdown]
# # Practice using names and operators in Python
#
# We’ve found that it’s helpful for students who are brand new to
# programming to have some practice with the basic syntax. If that’s you,
# that’s what this notebook is for - we hope it helps with getting used to
# Python. If you’re someone with more experience, don’t overthink it -
# just move on quickly to the analysis for this week!
#
# Be sure you have read the following chapters of the Introduction to
# Earth Data Science online textbook:
#
# -   **Section 4: Chapter 10**
#     <a href="https://earthdatascience.org/courses/intro-to-earth-data-science/python-code-fundamentals/" target="_blank">Chapter 10 - Get Started with Python Variables and Lists </a>
# -   **Chapter 4 Lesson 3**
# -   **Section 7: Chapter 16**
#     <a href="https://earthdatascience.org/courses/intro-to-earth-data-science/write-efficient-python-code/" target="_blank">Chapter 16 - Write Clean Expressive Code </a>
#
# These chapters cover:
#
# -   how to create and work with variables and lists
# -   more background on **Python** packages and environments
# -   how to write clean code, including an introduction to the PEP 8 style guide for **Python**.
#
# ## Assignment Data
#
# This data in this assignment represent average monthly temperature for
# <a href="https://www.esrl.noaa.gov/psd/boulder/Boulder.mm.html" target="_blank">Boulder,
# Colorado, provided by the U.S. National Oceanic and Atmospheric
# Administration (NOAA).</a>
#
# ## Create Variables in Python
#
# Add your code to the cell below to complete the following task:
#
# -   Create a unique variable that represents the monthly average
#     temperature (Fahrenheit) for each month January through March.
# -   Name each variable using the "Month" column name. You should have 3
#     variables in total. (`jan`, `feb`, and `march`)
#
# IMPORTANT: Python variable names are CASE SENSITIVE! Be sure that you
# spell the variable name correctly and consider capitalization.
#
# | Month | Temperature (Fahrenheit) |
# |-------|--------------------------|
# | jan   | 32.0                     |
# | feb   | 35.6                     |
# | mar   | 41.0                     |

# %%
### create variables of monthly temp
# Out:
# 108.6

# %% [markdown]
# Did you create all the variables? Run the cell below to find out (do not modify the code in this cell!):

# %%
### create a boolean (true/false) variable named "variables_exist"
### set it equal to False. if the variables were made correctly, this will change to True
variables_exist = False

### try running the following code. if any lines fail, skip to "except"
try:

    ### grab values stored in "jan," "feb," and "march" and add them together
    ### round the sum to 1 decimal place
    checksum = round(jan + feb + mar, 1)

    ### print a message if the previous line ran
    print("\u2705 Nice work - all of your variables exist!")

    ### update status of variables_exist if the previous lines ran
    variables_exist = True

### what to do if the previous lines of code don't run
### store error object in variable called "ne"
except NameError as ne:

    ### print error message including details stored in ne
    print(("\u274C Oops! At least one of your variables is missing. "
           "Be sure that all your variables are spelled exactly as it is "
           "represented in the Month column in the table above"), 
          ne)

### if variables_exist = True, run this code:
if variables_exist:

    ### make sure checksum is the correct value
    if checksum == 108.6:

        ### print message
        print("\u2705 All of your variables are set to the correct values.")

    ### if checksum is a different value than expected, print error message
    else:
        print(("\u274C You variables exist, but at least one does not have "
               "the correct value (the sum is incorrect)."))
# Out:
# ✅ Nice work - all of your variables exist!
# ✅ All of your variables are set to the correct values.

# %% [markdown]
# ## Run Calculations on Variables
#
# In the cell below, complete the following task:
#
# -   Convert the 3 variable values for January through March that you
#     created above **from Fahrenheit to Celsius** using the following
#     equation:
#     -   Celsius = (Fahrenheit - 32) / 1.8
#     -   Note that Python by default follows the standard rules of math
#         order of operations. This means that division would happen
#         BEFORE subtraction. Including `Fahrenheit - 32` within
#         parenthesis `()` tells `Python` to execute that calculation
#         first.

# %%
### convert variable values from Fahrenheit to Celsius
# Out:
# 7.0

# %% [markdown]
# Make sure you performed your conversion correctly by running the cell below. Do not modify the code in this cell!

# %%
### set correct value for summed temperature values in celsius
checksum_celsius = 7.0

### see whether the sum of jan + feb + march = the value stored in checksum_celsius
if round(jan + feb + mar, 1) == checksum_celsius:

    ### print message
    print(("\u2705 You modified the variables you created above correctly, "
           "good job!"))

### print error message
else:
    print(("\u274C You did not modify the variables as expected. Make sure "
           "you assigned the output of your modification back to the "
           "variable."))
# Out:
# ✅ You modified the variables you created above correctly, good job!

# %% [markdown]
# ## Create List of Converted Monthly Temperatures
#
# In the cell below, create a Python object of type **list** called **temp** for average monthly temperature for Boulder, CO containing the **variables for January to March in degrees Celsius**.
#
# In Python, lists are created by placing values inside square brackets `[]`, with items in the list separated by columns. For example, a list with two values would be created list this:
#
# `my_list = [value1, value2]`

# %%
### create list of converted monthly temps
# Out:
# [0.0, 2.000000000000001, 5.0]

# %% [markdown]
# Make sure you created your list correctly by running the following cell, without modifying the code in the cell:

# %%
### create boolean variable and set it to False
is_list = False

### see if temp is a list
if isinstance(temp, list):

    ### print message
    print(("\u2705 Nice work! The object you called at the end of the cell "
           "is of type - list"))

    ### update value of is_list
    is_list = True

### print error message
else:
    print(("\u274C Oops! Did you create a list variable and call it at the "
           "end of the cell? Please reread the directions."))

### run this chunk if temp is a list
if is_list:

    ### make sure temp has 3 values in it
    if len(temp) == 3:

        ### print message
        print(("\u2705 Nice work! Your list has the correct number of "
               "elements"))

    ### print error message
    else:
        print(("\u274C Oops - your list is not the correct length."))
    
### see if values sum to the correct number
if round(sum(temp), 1) == checksum_celsius:
    print(("\u2705 The list you created has the correct values in it, good "
           "job!"))

### print error message
else:
    print("\u274C The list you created does not contain the correct values.")
# Out:
# ✅ Nice work! The object you called at the end of the cell is of type - list
# ✅ Nice work! Your list has the correct number of elements
# ✅ The list you created has the correct values in it, good job!

# %% [markdown]
# ## Add Values to List of Converted Monthly Temperatures
#
# In the cell below, add the average monthly temperature values for **July to December in degrees Celsius** (in the table below) to your list called `temp` of converted monthly temperatures. \> HINT: There are actually 3 different ways you could complete this task: `.append()`, `.extend()`, or `+=`. Try out all 3 for practice!
#
# Print your completed list of converted monthly temperatures (in degrees Celsius).
#
# | Month | Temperature (Celsius) |
# |-------|-----------------------|
# | apr   | 9.6                   |
# | may   | 14.4                  |
# | june  | 19.6                  |
# | july  | 22.8                  |
# | aug   | 21.7                  |
# | sept  | 16.7                  |
# | oct   | 11.6                  |
# | nov   | 4.9                   |
# | dec   | 1.0                   |

# %%
### add to your list
# Out:
# 129.3
# [0.0,
#  2.000000000000001,
#  5.0,
#  9.6,
#  14.4,
#  19.6,
#  22.8,
#  21.7,
#  16.7,
#  11.6,
#  4.9,
#  1.0]

# %% [markdown]
# Check that you added the values to your list correctly by running the following code (without modifying it)

# %%
temp_long = _

### create boolean variable and set it to False
is_list = False

### check if it's a list
if isinstance(temp_long, list):
    print(("\u2705 Nice work! The object you called at the end of the cell "
           "is of type - list"))
    is_list = True
else:
    print(("\u274C Oops! Did you create a list variable and call it at the "
           "end of the cell? Please reread the directions."))

### check if the list is the right length
if is_list:
    if len(temp_long) == 12:
        print(("\u2705 Nice work! Your list has the correct number of "
               "elements"))
    else:
        print(("\u274C Oops - your list is not the correct length."))

### check if the list sums to the correct value    
if round(sum(temp_long), 1) == 129.3:
    print(("\u2705 The list you created has the correct values in it, good "
           "job!"))
else:
    print("\u274C The list you created does not contain the correct values.")
# Out:
# ✅ Nice work! The object you called at the end of the cell is of type - list
# ✅ Nice work! Your list has the correct number of elements
# ✅ The list you created has the correct values in it, good job!
#
#  ➡ You received 7 out of 7 points for creating a list of the temperatures January-June.
# 7

# %% [markdown]
# ## <i class="fa fa-pencil-square-o" aria-hidden="true"></i> BONUS Challenge: List Comprehensions in Python (OPTIONAL)
#
# You just performed many tasks manually. Included in those manual steps was one where you converted each individual value in your list from Fahrenheit to Celsius. In **Python**, list comprehensions are a great way to perform operations on a sequence of values stored within a list.
#
# The syntax for a list comprehension is below. Essentially what is happening is that Python is iterating through each value in the old list (`for i in my_old_list`) and multiplying it by 2 (`i*2`). In each iteration of the loop, the value `i` represents the next value in the list. In the example below, `i` will first be the value 1, and then 2, and finally 3.
#
# ``` python
# my_old_list = [1, 2, 3]
# my_new_list = [i*2 for i in my_old_list]
# ```
#
# `my_new_list` will equal each value in `my_old_list` multiplied by 2, so `my_new_list` will be equivalent to `[2, 4, 6]`. You can run this code and see the output for yourself.
#
# Try to experiment with writing more efficient code. Convert your `temp_fah` list of values to a new list called `temp_cel` using a list comprehension. Use the syntax above to help you create this list comprehension.
#
#
# The code below creates a list object called temp_fah that stores 6 temperature values in degrees Fahrenheit:
#
# `temp_fah = [32.0, 35.6, 41.0, 49.2, 57.9, 67.2]`
#
# Do the following:
#
# 1.  Copy the code into the code cell below
# 2.  Create a list comprehension that creates a new object which contains each value converted into Celsius.
# 3.  Call the new list you created at the end of the cell.

# %%
### add your code here
# Out:
# 50.5
# [0.0,
#  2.000000000000001,
#  5.0,
#  9.555555555555557,
#  14.388888888888888,
#  19.555555555555557]

# %% [markdown]
# You can check if your code worked by running the chunk below:

# %%
student_temp_cel = _

### check that it's a list
if isinstance(student_temp_cel, list):
    print(("\u2705 Nice work! The object you called at the end of the cell "
           "is of type - list"))
    is_list = True
else:
    print(("\u274C Oops! Did you create a list variable and call it at the "
           "end of the cell? Please reread the directions."))

if is_list:
    ### check that the list is the correct length
    if len(student_temp_cel) == 6:
        print(("\u2705 Nice work! Your list has the correct number of "
               "elements"))
    else:
        print(("\u274C Oops - your list is not the correct length."))

    ### check that the list sums to the correct value
    if round(sum(student_temp_cel), 1) == 50.5:
        print(("\u2705 Your list comprehension output has the correct "
               "values in it."))
    else:
        print(("\u274C Your list comprehension output does not have the "
               "correct values in it."))
# Out:
# ✅ Nice work! The object you called at the end of the cell is of type - list
# ✅ Nice work! Your list has the correct number of elements
# ✅ Your list comprehension output has the correct values in it.

# %% [markdown]
# ### Learn More About For Loops and List Comprehensions in Python (OPTIONAL)
#
# For more information on loops and changing values within a list, you can
# check out:
#
# -   <a href="https://www.earthdatascience.org/courses/intro-to-earth-data-science/write-efficient-python-code/loops/" target="_blank">Earth
#     Lab’s lesson introducing loops in Python,</a> and
# -   <a href="https://www.earthdatascience.org/courses/intro-to-earth-data-science/write-efficient-python-code/loops/list-comprehensions" target="_blank">Earth
#     Lab’s lesson on list comprehensions in Python.</a>
